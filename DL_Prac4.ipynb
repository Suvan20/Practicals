# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
import datetime
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.metrics import r2_score

# %%
data = pd.read_csv('Google_Stock_Price_Train.csv',thousands=',')
data
# Out:
#             Date    Open    High     Low   Close    Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7380500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5749400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6590300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5405900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11688800
# ...          ...     ...     ...     ...     ...       ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91    623400
# 1254  12/27/2016  790.68  797.86  787.66  791.55    789100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1153800
# 1256  12/29/2016  783.33  785.93  778.92  782.79    744300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1770000
#
# [1258 rows x 6 columns]

# %%
ax1 = data.plot(x="Date", y=["Open", "High", "Low", "Close"], figsize=(10,7),title='Open, High, Low, Close Stock Prices of Google Stocks')
ax1.set_ylabel("Stock Price")

ax2 = data.plot(x="Date", y=["Volume"],  figsize=(10,7))
ax2.set_ylabel("Stock Volume")
# Out:
# Text(0, 0.5, 'Stock Volume')

# %%
data.isna().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
data[['Open','High','Low','Close','Volume']].plot(kind='box', layout=(1,5), subplots=True, sharex=False, sharey=False, figsize=(10,7),color='red')
plt.show()

# %%
data.hist(figsize=(10,7))
plt.show()

# %%
scaler = MinMaxScaler()
data_without_date = data.drop("Date", axis=1)
scaled_data = pd.DataFrame(scaler.fit_transform(data_without_date))

scaled_data.hist(figsize=(10,7))
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data.drop("Date", axis=1).corr())
plt.show()

# %%
scaled_data = scaled_data.drop([0, 2, 3], axis=1)
scaled_data
# Out:
#              1         4
# 0     0.096401  0.295258
# 1     0.098344  0.229936
# 2     0.092517  0.263612
# 3     0.088819  0.216179
# 4     0.076718  0.467797
# ...        ...       ...
# 1253  0.955292  0.024650
# 1254  0.964853  0.031286
# 1255  0.958074  0.045891
# 1256  0.942574  0.029491
# 1257  0.936691  0.070569
#
# [1258 rows x 2 columns]

# %%
def split_seq_multivariate(sequence, n_past, n_future):

    '''
    n_past ==> no of past observations
    n_future ==> no of future observations
    '''
    x = []
    y = []
    for window_start in range(len(sequence)):
        past_end = window_start + n_past
        future_end = past_end + n_future
        if future_end > len(sequence):
            break
        # slicing the past and future parts of the window (this indexing is for 2 features vala data only)
        past = sequence[window_start:past_end, :]
        future = sequence[past_end:future_end, -1]
        x.append(past)
        y.append(future)

    return np.array(x), np.array(y)

# %%
n_steps = 60

scaled_data = scaled_data.to_numpy()
scaled_data.shape
# Out:
# (1258, 2)

# %%
x, y = split_seq_multivariate(scaled_data, n_steps, 1)

# %%
x.shape, y.shape
# Out:
# ((1198, 60, 2), (1198, 1))

# %%
y = y[:, 0]
y.shape
# Out:
# (1198,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=42)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((958, 60, 2), (240, 60, 2), (958,), (240,))

# %%
model = Sequential()
model.add(LSTM(612, input_shape=(n_steps, 2)))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(1))
# Out:
# C:\Users\Suvan\anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 612)            │     1,505,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │        30,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 30)             │         1,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,540,281 (5.88 MB)
#  Trainable params: 1,540,281 (5.88 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=32, verbose=2, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 30/30 - 13s - 441ms/step - loss: 0.0065 - mae: 0.0478 - val_loss: 0.0069 - val_mae: 0.0481
# Epoch 2/50
# 30/30 - 9s - 291ms/step - loss: 0.0047 - mae: 0.0403 - val_loss: 0.0049 - val_mae: 0.0451
# Epoch 3/50
# 30/30 - 9s - 288ms/step - loss: 0.0044 - mae: 0.0378 - val_loss: 0.0055 - val_mae: 0.0413
# Epoch 4/50
# 30/30 - 9s - 285ms/step - loss: 0.0043 - mae: 0.0362 - val_loss: 0.0045 - val_mae: 0.0417
# Epoch 5/50
# 30/30 - 8s - 279ms/step - loss: 0.0042 - mae: 0.0372 - val_loss: 0.0044 - val_mae: 0.0392
# Epoch 6/50
# Epoch 31/50
# 30/30 - 10s - 317ms/step - loss: 0.0033 - mae: 0.0313 - val_loss: 0.0035 - val_mae: 0.0371
# Epoch 32/50
# 30/30 - 11s - 371ms/step - loss: 0.0034 - mae: 0.0325 - val_loss: 0.0034 - val_mae: 0.0362
# Epoch 33/50
# 30/30 - 10s - 322ms/step - loss: 0.0033 - mae: 0.0313 - val_loss: 0.0034 - val_mae: 0.0346
# Epoch 34/50
# 30/30 - 10s - 342ms/step - loss: 0.0034 - mae: 0.0326 - val_loss: 0.0032 - val_mae: 0.0351
# Epoch 35/50
# 30/30 - 10s - 321ms/step - loss: 0.0035 - mae: 0.0328 - val_loss: 0.0033 - val_mae: 0.0358
# Epoch 36/50
# 30/30 - 9s - 315ms/step - loss: 0.0034 - mae: 0.0316 - val_loss: 0.0034 - val_mae: 0.0358
# Epoch 37/50
# 30/30 - 9s - 312ms/step - loss: 0.0035 - mae: 0.0334 - val_loss: 0.0033 - val_mae: 0.0361
# Epoch 38/50
# 30/30 - 9s - 307ms/step - loss: 0.0034 - mae: 0.0325 - val_loss: 0.0033 - val_mae: 0.0351
# Epoch 39/50
# 30/30 - 9s - 310ms/step - loss: 0.0033 - mae: 0.0312 - val_loss: 0.0034 - val_mae: 0.0347
# Epoch 40/50
# 30/30 - 9s - 306ms/step - loss: 0.0033 - mae: 0.0316 - val_loss: 0.0033 - val_mae: 0.0353
# Epoch 41/50
# 30/30 - 9s - 309ms/step - loss: 0.0034 - mae: 0.0322 - val_loss: 0.0035 - val_mae: 0.0352
# Epoch 42/50
# 30/30 - 9s - 316ms/step - loss: 0.0033 - mae: 0.0317 - val_loss: 0.0034 - val_mae: 0.0347
# Epoch 43/50
# 30/30 - 9s - 312ms/step - loss: 0.0033 - mae: 0.0320 - val_loss: 0.0037 - val_mae: 0.0397
# Epoch 44/50
# 30/30 - 9s - 314ms/step - loss: 0.0034 - mae: 0.0327 - val_loss: 0.0033 - val_mae: 0.0376
# Epoch 45/50
# 30/30 - 9s - 309ms/step - loss: 0.0034 - mae: 0.0324 - val_loss: 0.0034 - val_mae: 0.0368
# Epoch 46/50
# 30/30 - 10s - 318ms/step - loss: 0.0034 - mae: 0.0319 - val_loss: 0.0034 - val_mae: 0.0357
# Epoch 47/50
# 30/30 - 10s - 321ms/step - loss: 0.0033 - mae: 0.0320 - val_loss: 0.0033 - val_mae: 0.0355
# Epoch 48/50
# 30/30 - 9s - 313ms/step - loss: 0.0034 - mae: 0.0333 - val_loss: 0.0035 - val_mae: 0.0359
# Epoch 49/50
# 30/30 - 10s - 318ms/step - loss: 0.0033 - mae: 0.0321 - val_loss: 0.0034 - val_mae: 0.0349
# Epoch 50/50
# 30/30 - 9s - 306ms/step - loss: 0.0033 - mae: 0.0309 - val_loss: 0.0036 - val_mae: 0.0342

# %%
pd.DataFrame(history.history).plot(figsize=(10,7))
# Out:
# <Axes: >

# %%
model.evaluate(x_test, y_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0032 - mae: 0.0329
# [0.00359328743070364, 0.03422258049249649]

# %%
predictions = model.predict(x_test)
predictions.shape
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# (240, 1)

# %%
plt.plot(y_test, c = 'r')
plt.plot(predictions, c = 'y')
plt.xlabel('Day')
plt.ylabel('Stock Price Volume')
plt.title('Stock Price Volume Prediction Graph using RNN (LSTM)')
plt.legend(['Actual','Predicted'], loc = 'lower right')
plt.figure(figsize=(10,7))
plt.show()
